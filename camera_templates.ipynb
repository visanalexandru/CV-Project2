# %%
# %load_ext autoreload
# %autoreload 2

# %%
from video import *
import matplotlib.pyplot as plt

# %%
video_a = load_video("train/task1/02_reference.mp4")
video_b = load_video("train/task1/01_reference.mp4")
video_c = load_video("train/task1/01_query.mp4")

# %%
camera_a = video_a.get_frame(0)
camera_b = video_b.get_frame(0)
camera_c = video_c.get_frame(0)

# %%
plt.title("Camera A template")
plt.imshow(camera_a)

# %%
plt.title("Camera B template")
plt.imshow(camera_b)

# %%
plt.title("Camera C template")
plt.imshow(camera_c)

# %%
camera_a_gray = cv.cvtColor(camera_a, cv.COLOR_RGB2GRAY)
camera_b_gray = cv.cvtColor(camera_b, cv.COLOR_RGB2GRAY)
camera_c_gray = cv.cvtColor(camera_c, cv.COLOR_RGB2GRAY)

# %%
cv.imwrite("camera_templates/camera_a.png", camera_a_gray)
cv.imwrite("camera_templates/camera_b.png", camera_b_gray)
cv.imwrite("camera_templates/camera_c.png", camera_c_gray)
# Out:
# True

# %%
plt.title("The image above the horizon line for camera A")
plt.imshow(crop_horizon(camera_a_gray))

# %%
plt.title("The image above the horizon line for camera B")
plt.imshow(crop_horizon(camera_b_gray))

# %%
plt.title("The image above the horizon line for camera C")
plt.imshow(crop_horizon(camera_c_gray))
